# %%
import pandas as pd
import json
import jsonlines
import torch
import torch.nn as nn
import torch.nn.functional as F
import matplotlib.pyplot as plt

# %%
# torch.save(v, "/home/zymrael/checkpoints/evo2/7b-ablations-n32/7b_stripedhyena2_base_4M_resume/v2_vortex.pt")
torch.save(
    x,
    f"/home/zymrael/checkpoints/evo2/7b-ablations-n32/7b_stripedhyena2_base_4M_resume/vortex/post_block_{block_idx}.pt",
)
torch.save(
    output,
    f"/home/zymrael/checkpoints/evo2/7b-ablations-n32/7b_stripedhyena2_base_4M_resume/savanna/post_block_{self.layer_number}.pt",
)

# %%
# torch.save(v, "/home/zymrael/checkpoints/evo2/7b-ablations-n32/7b_stripedhyena2_base_4M_resume/v2_vortex.pt")
torch.save(
    z,
    f"/home/zymrael/checkpoints/evo2/7b-ablations-n32/7b_stripedhyena2_base_4M_resume/vortex/x2y_{self.layer_idx}.pt",
)
torch.save(
    z,
    f"/home/zymrael/checkpoints/evo2/7b-ablations-n32/7b_stripedhyena2_base_4M_resume/savanna/x2y_{self.layer_number}.pt",
)

# %%
logits_savanna = torch.load(f"../../../../logits_savanna")
logits_vortex = torch.load(f"../../../../logits_vortex")[0]
# Out:
# /tmp/ipykernel_3755065/2338514354.py:1: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   logits_savanna = torch.load(f"../../../../logits_savanna")
# ...

# %%
logits_savanna.shape
# Out:
# torch.Size([1, 16, 512])

# %%
fig, axs = plt.subplots(4, 4, figsize=(16, 8))
for i in range(4):
    for j in range(4):
        err = logits_savanna[0, 4 * j + i] - logits_vortex[0, 4 * j + i]
        axs[j, i].plot(
            logits_savanna[0, 4 * j + i].flatten().detach().float().cpu().numpy()
        )
        axs[j, i].plot(
            logits_vortex[0, 4 * j + i].flatten().detach().float().cpu().numpy()
        )
plt.suptitle("Logits (vortex and savanna) 7B SHC-2 (NVIDIA), prompt: ACTGACTGACTGACTG")
plt.show()

# %%
x1v_2_savanna = torch.load(
    f"/home/zymrael/checkpoints/evo2/7b-ablations-n32/7b_stripedhyena2_base_4M_resume/savanna/x1v_2.pt"
)
x1v_2_vortex = torch.load(
    f"/home/zymrael/checkpoints/evo2/7b-ablations-n32/7b_stripedhyena2_base_4M_resume/vortex/x1v_2.pt"
)
x1v_1_savanna = torch.load(
    f"/home/zymrael/checkpoints/evo2/7b-ablations-n32/7b_stripedhyena2_base_4M_resume/savanna/x1v_1.pt"
)
x1v_1_vortex = torch.load(
    f"/home/zymrael/checkpoints/evo2/7b-ablations-n32/7b_stripedhyena2_base_4M_resume/vortex/x1v_1.pt"
)
x2y_1_savanna = torch.load(
    f"/home/zymrael/checkpoints/evo2/7b-ablations-n32/7b_stripedhyena2_base_4M_resume/savanna/x2y_1.pt"
)
x2y_1_vortex = torch.load(
    f"/home/zymrael/checkpoints/evo2/7b-ablations-n32/7b_stripedhyena2_base_4M_resume/vortex/x2y_1.pt"
)

post_block_0_savanna = torch.load(
    f"/home/zymrael/checkpoints/evo2/7b-ablations-n32/7b_stripedhyena2_base_4M_resume/savanna/post_block_0.pt"
)
post_block_0_vortex = torch.load(
    f"/home/zymrael/checkpoints/evo2/7b-ablations-n32/7b_stripedhyena2_base_4M_resume/vortex/post_block_0.pt"
)
post_block_1_savanna = torch.load(
    f"/home/zymrael/checkpoints/evo2/7b-ablations-n32/7b_stripedhyena2_base_4M_resume/savanna/post_block_1.pt"
)
post_block_1_vortex = torch.load(
    f"/home/zymrael/checkpoints/evo2/7b-ablations-n32/7b_stripedhyena2_base_4M_resume/vortex/post_block_1.pt"
)
post_block_2_savanna = torch.load(
    f"/home/zymrael/checkpoints/evo2/7b-ablations-n32/7b_stripedhyena2_base_4M_resume/savanna/post_block_2.pt"
)
post_block_2_vortex = torch.load(
    f"/home/zymrael/checkpoints/evo2/7b-ablations-n32/7b_stripedhyena2_base_4M_resume/vortex/post_block_2.pt"
)
# Out:
# /tmp/ipykernel_3755065/3926817401.py:1: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
# ...

# %%
post_block_1_savanna[0, -1].shape
# Out:
# torch.Size([4096])

# %%
plt.plot(
    (post_block_1_savanna[0, 5] - post_block_1_vortex[0, 5])
    .abs()
    .flatten()
    .detach()
    .float()
    .cpu()
    .numpy()
)

# %%
post_block_1_savanna[0, :, 0], post_block_1_vortex[0, :, 0]
# Out:
# (tensor([-0.0024, -0.0157, -0.0115,  0.0031,  0.0130, -0.0048,  0.0092,  0.0096,
#          -0.0020,  0.0118,  0.0057, -0.0096,  0.0028,  0.0177,  0.0175, -0.0076],
#         device='cuda:0', dtype=torch.bfloat16, grad_fn=<SelectBackward0>),
#  tensor([-0.0022, -0.0117, -0.0110,  0.0030,  0.0149, -0.0050,  0.0032,  0.0068,
#           0.0021,  0.0098,  0.0032, -0.0136,  0.0044,  0.0114,  0.0063, -0.0139],
#         device='cuda:0', dtype=torch.bfloat16, grad_fn=<SelectBackward0>))

# %%
post_block_0_savanna.max(), post_block_0_vortex.max()
# post_block_0_savanna.min(), post_block_0_vortex.min()
# Out:
# (tensor(0.2969, device='cuda:0', dtype=torch.bfloat16, grad_fn=<MaxBackward1>),
#  tensor(0.2988, device='cuda:0', dtype=torch.bfloat16, grad_fn=<MaxBackward1>))

# %%
post_block_2_savanna[0, 0].shape
# Out:
# torch.Size([4096])

# %%
post_block_2_savanna[0, t_idx], post_block_2_vortex[0, t_idx]
# Out:
# (tensor([ 0.0240,  0.0344, -0.0869,  ...,  0.0181, -0.0747,  0.0535],
#         device='cuda:0', dtype=torch.bfloat16, grad_fn=<SelectBackward0>),
#  tensor([ 0.0132,  0.0082, -0.0742,  ...,  0.0306, -0.0850,  0.0601],
#         device='cuda:0', dtype=torch.bfloat16, grad_fn=<SelectBackward0>))

# %%
t_idx = 5
plt.plot(
    (post_block_0_savanna[0, t_idx] - post_block_0_vortex[0, t_idx])
    .abs()
    .flatten()
    .detach()
    .float()
    .cpu()
    .numpy()
)
plt.show()

# %%
plt.plot(
    (post_block_2_savanna - post_block_2_vortex)
    .abs()[0]
    .flatten()
    .detach()
    .float()
    .cpu()
    .numpy()
)

# %%
plt.plot(
    (x2y_2_savanna - x2y_2_vortex).abs()[0].flatten().detach().float().cpu().numpy()
    / x2y_1_vortex.abs()[0].flatten().detach().float().cpu().numpy()
)
plt.show()
# Out:
# /tmp/ipykernel_3755065/3897573163.py:1: RuntimeWarning: divide by zero encountered in divide
#   plt.plot((x2y_1_savanna - x2y_1_vortex).abs()[0].flatten().detach().float().cpu().numpy() / x2y_1_vortex.abs()[0].flatten().detach().float().cpu().numpy())

# %%
x1v_2_savanna.max(), x1v_2_vortex.max()
# x1v_2_savanna.min(), x1v_2_vortex.min()
# Out:
# (tensor(7.5312, device='cuda:0', dtype=torch.bfloat16, grad_fn=<MaxBackward1>),
#  tensor(6.0938, device='cuda:0', dtype=torch.bfloat16, grad_fn=<MaxBackward1>))

# %%
plt.plot(
    (x1v_1_savanna - x1v_1_vortex).abs()[0].flatten().detach().float().cpu().numpy()
)
plt.show()

# %%
plt.plot(
    (x1v_1_savanna - x1v_1_vortex).abs()[0].flatten().detach().float().cpu().numpy()
)
plt.show()

# %%
(x1v_savanna - x1v_vortex).abs()
# Out:
# tensor([[[3.1662e-04, 2.7771e-03, 8.7891e-03,  ..., 6.1035e-03,
#           6.8359e-03, 4.2725e-03],
#          [2.2736e-03, 1.8921e-03, 2.0020e-02,  ..., 3.3379e-04,
#           1.2512e-03, 2.3270e-04],
#          [2.3270e-04, 9.9182e-05, 1.7395e-03,  ..., 2.7466e-04,
#           3.1128e-03, 3.0518e-03],
#          ...,
#          [4.2419e-03, 2.4414e-03, 1.4801e-03,  ..., 4.2725e-04,
#           2.4414e-04, 9.1553e-05],
#          [2.4414e-03, 1.2970e-03, 4.6387e-03,  ..., 3.9062e-03,
#           1.7776e-03, 3.6621e-04],
#          [5.0545e-05, 5.2643e-04, 2.4902e-02,  ..., 4.3030e-03,
#           1.2207e-03, 7.3242e-04]]], device='cuda:0', dtype=torch.bfloat16,
#        grad_fn=<AbsBackward0>)

# %%
v2_savanna = torch.load(
    "/home/zymrael/checkpoints/evo2/7b-ablations-n32/7b_stripedhyena2_base_4M_resume/v2_savanna.pt"
)
v2_vortex = torch.load(
    "/home/zymrael/checkpoints/evo2/7b-ablations-n32/7b_stripedhyena2_base_4M_resume/v2_vortex.pt"
)
# Out:
# /tmp/ipykernel_3755065/34261535.py:1: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
# ...

# %%
for k in range(100):
    plt.plot(err[0, k])

# %%
err = (v2_savanna - v2_vortex).abs().detach().float().cpu().numpy()
print(err.max())
print(err.min())
print(err.mean())
# Out:
# 0.8828125
# 0.0
# 0.03377073

# %%
v2_savanna.shape, v2_vortex.shape
# Out:
# (torch.Size([1, 4096, 16]), torch.Size([1, 4096, 16]))

# %%
x = torch.arange(3)[None, None]
h = torch.arange(3)[None, None].flip(-1)
y = F.conv1d(x, h)
print(x, y, h)
# Out:
# tensor([[[0, 1, 2]]]) tensor([[[1]]]) tensor([[[2, 1, 0]]])

# %%
qkv_savanna = (
    torch.load(f"/home/zymrael/checkpoints/evo2/activations/savanna/pre_flashattn_8.pt")
    .squeeze()
    .detach()
    .float()
    .cpu()
)
qkv_vortex = (
    torch.load(f"/home/zymrael/checkpoints/evo2/activations/vortex/pre_flashattn_8.pt")
    .squeeze()
    .detach()
    .float()
    .cpu()
)

print(qkv_savanna.shape)
print(qkv_vortex.shape)

diff = (qkv_savanna - qkv_vortex).abs().detach().float().cpu().numpy()
print(diff.max())
print(diff.min())
print(diff.mean())
print(qkv_vortex.shape, qkv_savanna.shape)
# Out:
# torch.Size([4, 3, 32, 128])
# torch.Size([4, 3, 32, 128])
# 14.8125
# 0.0
# 0.5234044
# torch.Size([4, 3, 32, 128]) torch.Size([4, 3, 32, 128])
# ...

# %%
qkv_vortex_2 = qkv_vortex.reshape(4, -1)
qkv_vortex_2 = qkv_vortex_2.reshape(4, 32, 3, 128)
q, k, v = qkv_vortex_2.unbind(-2)
qkv_vortex_2 = torch.cat([q.reshape(4, -1), k.reshape(4, -1), v.reshape(4, -1)], dim=-1)
qkv_vortex_2 = qkv_vortex_2.reshape(4, 3, 32, 128)

# %%
plt.plot(qkv_vortex_2[0, 0, -1])
plt.plot(qkv_savanna[0, 0, -1])
plt.show()

# %%
plt.plot(qkv_vortex[0, 0, 0])
plt.plot(qkv_savanna[0, 0, 0])
plt.show()

# %%
z = torch.load(f"/home/zymrael/checkpoints/evo2/activations/vortex/pre_filter_1.pt")
z_savanna = torch.load(
    f"/home/zymrael/checkpoints/evo2/activations/savanna/pre_filter_1.pt"
)
error = (z - z_savanna.squeeze()).abs().detach().float().cpu().numpy()
z = z.squeeze().detach().float().cpu().numpy()
z_savanna = z_savanna.squeeze().detach().float().cpu().numpy()
print(error)
print(error.max())
print(error.min())
print(error.mean())
# Out:
# [[[0.0000000e+00 9.7656250e-03 0.0000000e+00 ... 3.1250000e-02
#    7.6293945e-06 6.2500000e-02]
#   [0.0000000e+00 0.0000000e+00 0.0000000e+00 ... 0.0000000e+00
#    0.0000000e+00 0.0000000e+00]
#   [0.0000000e+00 3.1250000e-02 3.1250000e-02 ... 6.2500000e-02
#    0.0000000e+00 0.0000000e+00]
#   [0.0000000e+00 1.5625000e-02 0.0000000e+00 ... 1.5625000e-02
#    1.9073486e-06 0.0000000e+00]]]
# 1.0
# 0.0
# 0.013634346
# ...

# %%
z.shape
# Out:
# (4, 12288)

# %%
z.max()
# Out:
# 165.0

# %%
# plt.plot(error[0,0])
plt.plot(z[0])
plt.plot(z_savanna[0])
# plt.show()

# %%
bwd_test_log = "logs/parsed_test_bwd.log"
fwd_test_log = "logs/parsed_test_fwd.log"

# %%
raw_bwd_logs = [json.loads(line.strip()) for line in open(bwd_test_log).readlines()]

# %%
df = pd.DataFrame(raw_bwd_logs).drop("is_interpreter", axis=1)

# %%
group_keys = [k for k in df.columns if not ("DEBUG" in k)]
run_config_keys = [k for k in group_keys if not any(x in k for x in ["passed", "diff"])]
bwd_key_pats = ["dx", "dB", "dC", "dh"]
fwd_key_pat = ["return_", "y2_", "y_", "T_", "T_hat"]
common_keys = [
    k for k in run_config_keys if not any(x in k for x in bwd_key_pats + fwd_key_pat)
]
bwd_group_keys = [k for k in group_keys if not any(x in k for x in fwd_key_pat)]
fwd_group_keys = [k for k in group_keys if not any(x in k for x in bwd_key_pats)]

# %%
# Bwd tests sliced by TMA
bwd_tests = df[bwd_group_keys]
bwd_tests_TMA = bwd_tests[bwd_tests.USE_TMA]
bwd_tests_NO_TMA = bwd_tests[~bwd_tests.USE_TMA]

# %%
# These are fwd pass in e2e fwd / bwd tests
fwd_tests = df[df.y_diff.notna()][fwd_group_keys]
fwd_tests_TMA = fwd_tests[fwd_tests.USE_TMA]
fwd_tests_NO_TMA = fwd_tests[~fwd_tests.USE_TMA]

# %%
# Forward failures
y_failures = fwd_tests[fwd_tests.y_passed == False].sort_values(
    "y_diff", ascending=False
)[common_keys + ["y_diff"]]

# Backward failures
dx_failures = bwd_tests[bwd_tests.dx_passed == False].sort_values(
    "dx_diff", ascending=False
)[common_keys + ["dx_diff"]]
dB_failures = bwd_tests[bwd_tests.dB_passed == False].sort_values(
    "dB_diff", ascending=False
)[common_keys + ["dB_diff"]]
dC_failures = bwd_tests[bwd_tests.dC_passed == False].sort_values(
    "dC_diff", ascending=False
)[common_keys + ["dC_diff"]]
dh_failures = bwd_tests[bwd_tests.dh_passed == False].sort_values(
    "dh_diff", ascending=False
)[common_keys + ["dh_diff"]]

# %%
assert sum(y_failures.dtype == "float32") == 0
assert sum(dx_failures.dtype == "float32") == 0
assert sum(dB_failures.dtype == "float32") == 0
assert sum(dC_failures.dtype == "float32") == 0
assert sum(dh_failures.dtype == "float32") == 0
