# %%
import matplotlib.pyplot as plt

# %% [markdown]
# #### L = 256, D = 1024, B = 128, L_h = 4, H100

# %%
hyena_x_bdl_fwd = 1787.5313758850098e-3
hyena_x_fwd_causal_conv1d = 982.0222854614257e-3
hyena_x_fwd_ref = 1768.7439918518066e-3


plt.bar([0], hyena_x_bdl_fwd, width=0.2, edgecolor='black', alpha=0.7)
plt.bar([0.3], hyena_x_fwd_ref, width=0.2, edgecolor='black', alpha=0.7)
plt.bar([0.6], hyena_x_fwd_causal_conv1d, width=0.2, edgecolor='black', alpha=0.7)
plt.xticks([0, 0.3, 0.6], ['Custom', 'PyTorch', 'causal_conv1d'])
plt.ylabel('Time (ms)')
plt.show()

# %% [markdown]
# #### L = 256, D = 1024, B = 128, L_h = 7, H100

# %%
hyena_x_fwd_ref = 2012.0501518249512e-3
hyena_x_bdl_fwd = 1795.7448959350586e-3

plt.bar([0], hyena_x_bdl_fwd, width=0.2, edgecolor='black', alpha=0.7)
plt.bar([0.3], hyena_x_fwd_ref, width=0.2, edgecolor='black', alpha=0.7)
plt.xticks([0, 0.3], ['Custom', 'PyTorch'])
plt.ylabel('Time (ms)')
plt.show()

# %% [markdown]
# #### L = 256, D = 1024, B = 128, L_h = 16, H100

# %%
hyena_x_fwd_ref = 2329.3375968933105e-3
hyena_x_bdl_fwd = 1787.5313758850098e-3

plt.bar([0], hyena_x_bdl_fwd, width=0.2, edgecolor='black', alpha=0.7)
plt.bar([0.3], hyena_x_fwd_ref, width=0.2, edgecolor='black', alpha=0.7)
plt.xticks([0, 0.3], ['Custom', 'PyTorch'])
plt.ylabel('Time (ms)')
plt.show()

# %% [markdown]
# #### L = 256, D = 1024, B = 128, L_h = 32, H100

# %%
hyena_x_fwd_ref = 2944.8509216308594e-3
hyena_x_bdl_fwd = 2838.8619422912598e-3

plt.bar([0], hyena_x_bdl_fwd, width=0.2, edgecolor='black', alpha=0.7)
plt.bar([0.3], hyena_x_fwd_ref, width=0.2, edgecolor='black', alpha=0.7)
plt.xticks([0, 0.3], ['Custom', 'PyTorch'])
plt.ylabel('Time (ms)')
plt.show()
